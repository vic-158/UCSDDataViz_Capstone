# %%
import pandas as pd
SIA = pd.read_csv("SIA.csv")

# %%
SIA
# Out:
#        Unnamed: 0                                           Headline  \
# 0               0  #2816: Clinton Pride’s 8(a) Pig Farm Bridge – ...
# 1               1  #2817: Serco's Zulu Starnet Blackmail – Clinto...
# 2               2  Roger Stone update on Stop the Steal exit poll...
# 3               3  #2818: Serco's Zulu Bridge To Mumbai Pig Farm ...
# 4               4  Trump Advocates the American People's Control ...
# 5               5  FBI Weiner Probe Reopens Hillary Clinton Inves...
# 6               6  DOJ's Loretta Lynch Tried To Squash Comey's Le...
# 7               7  Scott Bennett, Whistleblower, U.S. Army Terror...
# 8               8  Do Not Forgive the MSM; Alt-Media, Our Job Is ...
# 9               9  Is it coming into clearer focus for Americans ...
# 10             10  Is This Why Comey Broke: A Stack Of Resignatio...
# 11             11  Why Hillary Clinton's Campaign Is Collapsing |...
# 12             12  #2820: Clinton 8(a) Pig Farm Servers – Boeing ...
# ...

# %%
headlines = pd.read_csv("output.csv")

# %%
merged_df= SIA.merge(headlines)

# %%
merged_df.to_csv("merged_df.csv")
