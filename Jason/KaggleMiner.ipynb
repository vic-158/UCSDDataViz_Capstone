# %%
import pandas as pd

# %%
 # The path to our CSV file
file = "fake_filtered_v2.csv"

# Read our Kickstarter data into pandas
df = pd.read_csv(file)
df.head()
# Out:
#    Unnamed: 0                                      uuid  ord_in_thread  \
# 0          59  b9af57aaf67e5894ea9cee78d8f646aecaa0ebd9              0
# 1          69  a3c854d3f9deceb87d031300016128124040c9a7              0
# 2          79  13fc2d922a6669ef992eeb7a701646bc04839e18              0
# 3          81  da9eac98db2b8bd73f0bc060b74c41e167b1dc30              0
# 4          84  56c77ca93df34d1ac4cd240afad84a8dd41029a6              0
#
#                              author                      published  \
# 0  tokyowashi (noreply@blogger.com)  2016-10-27T06:14:00.000+03:00
# 1  tokyowashi (noreply@blogger.com)  2016-10-28T03:19:50.476+03:00
# 2  tokyowashi (noreply@blogger.com)  2016-10-28T14:03:12.156+03:00
# 3  tokyowashi (noreply@blogger.com)  2016-10-28T23:31:03.391+03:00
# 4  tokyowashi (noreply@blogger.com)  2016-10-29T11:56:37.068+03:00
#
#                                                title  \
# 0  #2816: Clinton Pride’s 8(a) Pig Farm Bridge – ...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'uuid', 'ord_in_thread', 'author', 'published', 'title',
#        'text', 'language', 'crawled', 'site_url', 'country', 'domain_rank',
#        'thread_title', 'spam_score', 'main_img_url', 'replies_count',
#        'participants_count', 'likes', 'comments', 'shares', 'type'],
#       dtype='object')

# %%
df = df.drop(columns=['Unnamed: 0','uuid','ord_in_thread','author','crawled','domain_rank','thread_title','spam_score','site_url', 'country', 'domain_rank', 'main_img_url', 'replies_count',
       'participants_count', 'likes', 'comments', 'shares', 'type'])

# %%
filtered_fake_df = df.loc[(
    df["type"] == "bs")]
filtered_fake_df.head()
# Out:
#                                         uuid  ord_in_thread  \
# 59  b9af57aaf67e5894ea9cee78d8f646aecaa0ebd9              0
# 60  03905a0f06cb711190aad3934af253a0e1c00a83              1
# 61  42c16d3818e64ff4632409cafd309c22df530ac1              2
# 62  336f5dfbea5f263dbdd6ec9be9d1d94d255caa1f              3
# 63  ea086a28e0bbafcd9fbaabd728920337371d4876              4
#
#                               author                      published  \
# 59  tokyowashi (noreply@blogger.com)  2016-10-27T06:14:00.000+03:00
# 60                         Anonymous  2016-10-26T23:12:00.000+03:00
# 61                         Anonymous  2016-10-26T22:48:00.000+03:00
# 62                         Anonymous  2016-10-26T22:35:00.000+03:00
# 63                         Anonymous  2016-10-26T22:19:00.000+03:00
#
#                                                 title  \
# 59  #2816: Clinton Pride’s 8(a) Pig Farm Bridge – ...
# 60                                                NaN
# ...

# %%
df.to_csv('fake_filtered_v3.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-15-6c3a2b636f5e> in <module>()
# ----> 1 df.to_csv('fake_filtered_v3.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     154             f, handles = _get_handle(self.path_or_buf, self.mode,
#     155                                      encoding=encoding,
# ...

# %%
filtered_fake_df['site_url'].value_counts()
# Out:
# conservativetribune.com        100
# madworldnews.com               100
# blacklistednews.com            100
# investmentwatchblog.com        100
# opednews.com                   100
# guardianlv.com                 100
# ijr.com                        100
# dailystormer.com               100
# thefederalistpapers.org        100
# truthfeed.com                  100
# sputniknews.com                100
# mintpressnews.com              100
# jewsnews.co.il                 100
# amren.com                      100
# abovetopsecret.com             100
# rbth.com                       100
# trueactivist.com               100
# ihavethetruth.com              100
# thetruthseeker.co.uk           100
# pravda.ru                      100
# collective-evolution.com       100
# abeldanger.net                 100
# naturalblaze.com               100
# freedomoutpost.com             100
# shiftfrequency.com             100
# thenewamerican.com             100
# thefreethoughtproject.com      100
# ...

# %%
filtered_fake_df['country'].value_counts()
# Out:
# US    9253
# GB     715
# RU     400
# TV     200
# DE     122
# EU     112
# ES     100
# IS     100
# CA      91
# NL      55
# FR      51
# ME      34
# IN      23
# BG      19
# CO      16
# LI      10
# EE       4
# ZA       3
# IR       3
# SG       2
# AU       1
# CH       1
# SE       1
# Name: country, dtype: int64

# %%
len(filtered_fake_df)
# Out:
# 11492
