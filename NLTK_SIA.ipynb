# %%
# import nltk.classify.util
# from nltk.classify import NaiveBayesClassifier
# from nltk.corpus import names
# from nltk.tokenize import sent_tokenize, word_tokenize

# %%
# positive_vocab = []
# negative_vocab = []
# neutral_vocab = []

# %%
# with open('positive-words.txt') as f: 
#     for line in f:
#         positive_vocab.append(line.strip())
        
# print(positive_vocab)

# %%
# with open('negative-words.txt') as f: 
#     for line in f:
# #        print(line.rstrip())
#         negative_vocab.append(line.strip())
        
# print(negative_vocab)

# %%
# def word_feats(words): 
#     return dict([(word, True) for word in words])

# %%
# positive_features = [(word_feats(pos),'pos') for pos in positive_vocab]
# #negative_features = [({neg: True}, 'neg') for neg in negative_vocab]
# negative_features = [(word_feats(neg), 'neg') for neg in negative_vocab]
# negative_features

# %%
# positive_vocab = [ 'awesome', 'outstanding', 'fantastic', 'terrific', 'good', 'nice', 'great', ':)' ]
# negative_vocab = [ 'bad', 'terrible','useless', 'hate', ':(' ]
# neutral_vocab = [ 'movie','the','sound','was','is','actors','did','know','words','not' ]

# positive_features = [(word_feats(pos), 'pos') for pos in positive_vocab]
# negative_features = [(word_feats(neg), 'neg') for neg in negative_vocab]
# neutral_features = [(word_feats(neu), 'neu') for neu in neutral_vocab]
# positive_features

# %%
# for word in words: 
#     if (word not in positive_vocab and word not in negative_vocab):
#         neutral_vocab.append(word)

# neutral_features = [({neu: True}, 'neu') for neu in neutral_vocab]
# neutral_features

# %%
# # Predict
# neg = 0
# pos = 0
# neu = 0

# train_set = negative_features + positive_features + neutral_features
 
# classifier = NaiveBayesClassifier.train(train_set)

# for word in words:
#     classResult = classifier.classify( word_feats(word))
    
    
#     if classResult == 'neg':
#         print(neg)
#         neg = neg + 1
#     if classResult == 'pos':
#         print(pos)
#         pos = pos + 1
#     if classResult == 'neu':
#         neu = neu + 1

# print('Positive: ' + str(float(pos)/len(words)))
# print('Negative: ' + str(float(neg)/len(words)))
# print('Neutral: ' + str(float(neu)/len(words)))

# %%
sentence = "awesome liked it"
sentence = sentence.lower()
words = sentence.split(' ')

from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
import pandas as pd

# %%
df = pd.read_csv("out.csv")

# %%
headlines=df['Headline']
headlines
# Out:
# 0     God Orders All Followers To Swallow Cyanide Ca...
# 1     Supreme Court Rejects Adding Census Citizenshi...
# 2     Extremely Effective Therapist Just Lets Patien...
# 3                    Mueller To Testify Before Congress
# 4     Highlights Of The Democratic Primary Debate Day 2
# 5     CD Projekt Red Announces ‘Cyberpunk 2077’ Will...
# 6                          Illinois Legalizes Marijuana
# 7     Experts Say Earliest Warning Signs Of Mental H...
# 8     Naked Andrew Yang Emerges From Time Vortex To ...
# 9     Trump Picks Stephanie Grisham As New Press Sec...
# 10    Highlights Of The Democratic Primary Debate Day 1
# 11    Breaking New Ground: Beto O’Rourke Has Become ...
# 12    OSHA Special Ops Team Raids Local Office After...
# 13    Historians Reveal Aqueducts Were Only Small Po...
# 14    Driver Kind Of Bummed To See Other Car He Been...
# 15    Pence Declines To Say Whether Climate Change A...
# 16    13.5 Million Americans Tune In To Watch Animal...
# ...

# %%
sia = SIA()
results = []

for line in headlines:
    pol_score = sia.polarity_scores(line)
    pol_score['headline'] = line
    results.append(pol_score)

# %%
results
# Out:
# [{'neg': 0.0,
#   'neu': 0.87,
#   'pos': 0.13,
#   'compound': 0.2732,
#   'headline': 'God Orders All Followers To Swallow Cyanide Capsules In Preparation For Voyage To Alpha Centauri'},
#  {'neg': 0.271,
#   'neu': 0.424,
#   'pos': 0.305,
#   'compound': 0.1027,
#   'headline': 'Supreme Court Rejects Adding Census Citizenship Question'},
#  {'neg': 0.19,
#   'neu': 0.632,
#   'pos': 0.179,
#   'compound': -0.0534,
#   'headline': 'Extremely Effective Therapist Just Lets Patients Beat Shit Out Of Him For 45 Minutes'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'headline': 'Mueller To Testify Before Congress'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'headline': 'Highlights Of The Democratic Primary Debate Day 2'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
# ...

# %%
neg = []
neu = []
pos = []
compound = []
headline = []
for currDict in results:
    for k, v in currDict.items():

        if k == 'neg':
            neg.append(v)
        if k == 'pos':
            pos.append(v)
        if k == 'neu':
            neu.append(v)
        if k == 'compound':
            compound.append(v)
        if k == 'headline':
            headline.append(v)
# Out:
# [0.0,
#  0.271,
#  0.19,
#  0.0,
#  0.0,
#  0.0,
#  0.0,
#  0.112,
#  0.326,
#  0.0,
#  0.0,
#  0.0,
#  0.14,
#  0.0,
#  0.0,
#  0.327,
#  0.0,
#  0.222,
#  0.326,
#  0.0,
#  0.14,
#  0.0]

# %%
SIA =pd.DataFrame({ 'Headline': headline,
    'Negative': neg,
     'Positive': pos,
     'Neutral': neu,
     'Compound Score': compound, 

    })

# %%
SIA
# Out:
#                                              Headline  Negative  Positive  \
# 0   God Orders All Followers To Swallow Cyanide Ca...     0.000     0.130
# 1   Supreme Court Rejects Adding Census Citizenshi...     0.271     0.305
# 2   Extremely Effective Therapist Just Lets Patien...     0.190     0.179
# 3                  Mueller To Testify Before Congress     0.000     0.000
# 4   Highlights Of The Democratic Primary Debate Day 2     0.000     0.000
# 5   CD Projekt Red Announces ‘Cyberpunk 2077’ Will...     0.000     0.000
# 6                        Illinois Legalizes Marijuana     0.000     0.000
# 7   Experts Say Earliest Warning Signs Of Mental H...     0.112     0.000
# 8   Naked Andrew Yang Emerges From Time Vortex To ...     0.326     0.000
# 9   Trump Picks Stephanie Grisham As New Press Sec...     0.000     0.000
# 10  Highlights Of The Democratic Primary Debate Day 1     0.000     0.000
# 11  Breaking New Ground: Beto O’Rourke Has Become ...     0.000     0.091
# ...
