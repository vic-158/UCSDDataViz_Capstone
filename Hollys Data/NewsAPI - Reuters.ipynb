# %%
from newsapi.newsapi_client import NewsApiClient

# %%
# Init
newsapi = NewsApiClient(api_key='59e1a0cc6cf745f5bc0030c81799caf2')

# %%
# /v2/top-headlines
top_headlines = newsapi.get_top_headlines(q='',
                                          sources='bbc-news',
                                          language='en')

# %%
# /v2/everything
all_articles = newsapi.get_everything(sources='reuters',
                                      domains='reuters.com',
                                      from_param='2019-05-29',
                                      to='2019-06-28',
                                      language='en',
                                      sort_by='relevancy')

# %%
all_articles
# Out:
# {'status': 'ok',
#  'totalResults': 16230,
#  'articles': [{'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'UPDATE 1-Abercrombie & Fitch misses quarterly same-store sales estimates, shares fall',
#    'description': 'Abercrombie & Fitch Co missed Wall Street estimates for quarterly same-store sales due to slowing demand for its surf-themed Hollister apparel and forecast second-quarter sales below estimates on Wednesday, sending its shares down over 17%.',
#    'url': 'https://www.reuters.com/article/us-abercrombie-results-idUSKCN1SZ1EQ',
#    'urlToImage': 'https://s4.reutersmedia.net/resources/r/?m=02&d=20190529&t=2&i=1392134389&w=1200&r=LYNXNPEF4S0US',
#    'publishedAt': '2019-05-29T12:09:12Z',
# ...

# %%
articles = all_articles['articles']

# %%
for article in articles:
    print(article['title'])
# Out:
# UPDATE 1-Abercrombie & Fitch misses quarterly same-store sales estimates, shares fall
# Swiss court blocks Italy's bid for possible da Vinci portrait
# S&P 500 opens at two-month low as trade tensions mount
# "Backsliding" Turkey's EU bid slips further away: Commission
# CORRECTED (OFFICIAL)-Norway to shut at least 2 oilfields in case of strike -industry
# For the first time since 1930s, a Belgian king meets the far-right
# Too late to tweak Brexit backstop: Irish finance minister
# Durant still limited, unlikely to play in games 1-2
# Cuba legalizes private Wi-Fi networks in bid to boost connectivity
# U.S. judge approves Ruth Madoff $594,000 settlement with court - appointed trustee
# Netanyahu vows to win Israeli snap election
# U.S. judge approves Ruth Madoff $594,000 settlement with court-appointed trustee
# U.S. imposes new anti-dumping duties on Chinese mattresses, beer kegs
# Explainer: The main players in Israel's next election, the second this year
# ...

# %%
# /v2/sources
# sources = newsapi.get_sources()
